# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
address = "https://raw.githubusercontent.com/Jaeik-Jeong/RLES/main/"

data_price = pd.read_csv(address+'price.csv', index_col=0)
data_train_csv = pd.DataFrame(data_price['Price'][:1000])
data_val_csv   = pd.DataFrame(data_price['Price'][1000:1500])
data_test_csv  = pd.DataFrame(data_price['Price'][1500:2000])

# %%
# Data Preprocessing

Battery_Size = 1 #p.u.

max_price = max(data_price['Price'])

size_train0 = len(data_train_csv)
size_val0   = len(data_val_csv)
size_test0  = len(data_test_csv)

price_train = list(data_train_csv['Price']/max_price)
price_val = list(data_val_csv['Price']/max_price)
price_test = list(data_test_csv['Price']/max_price)

# %%
# Agent

n_layers         = 2
in_size          = 2
hidden_size      = 64
out_size         = 1
T_horizon        = 128
learning_rate    = 0.001
K_epoch          = 3
gamma            = 0.99
lmbda            = 0.95
eps_clip         = 0.1
C_value          = 1
var              = 0.1**2

class LSTM(nn.Module):
    def __init__(self):
        super(LSTM, self).__init__()
        self.fc_s  = nn.Linear(in_size, hidden_size)
        self.rnn   = nn.LSTM(hidden_size, hidden_size, n_layers, batch_first=True)
        self.fc_pi = nn.Linear(hidden_size, out_size)
        self.fc_v  = nn.Linear(hidden_size, 1)

    def pi(self, x, hidden):
        x = F.relu(self.fc_s(x))
        x = x.view(1, -1, hidden_size)
        x, hidden = self.rnn(x, hidden)
        pi = self.fc_pi(x)
        pi = pi.view(-1, out_size)
        return pi, hidden

    def v(self, x, hidden):
        x = F.relu(self.fc_s(x))
        x = x.view(1, -1, hidden_size)
        x, hidden = self.rnn(x, hidden)
        v = self.fc_v(x)
        v = v.view(-1, 1)
        return v

# %%
# Environment

E_max   = Battery_Size
P_max   = E_max
tdelta  = 0.5
soc_min = 0.1
soc_max = 0.9
a0 = -1.031; a1 = 35; a2 = 3.685; a3 = 0.2156; a4 = 0.1178; a5 = 0.3201
b0 = 0.1463; b1 = 30.27; b2 = 0.1037; b3 = 0.0584; b4 = 0.1747; b5 = 0.1288
c0 = 0.1063; c1 = 62.49; c2 = 0.0437; d0 = 0.0712; d1 = 61.4; d2 = 0.0288
N = 130*215*E_max/0.1
beta = 1/max_price

class Env():
    def __init__(self, L, data):
        self.data_imb = data
        self.lagrange = L
        self.state = []

    def reset(self):
        imb = self.data_imb[0]
        E = E_max/2
        state = [[imb, E]]
        self.state = state
        return state

    def step(self, action):
        imb = self.data_imb[len(self.state)]

        E = self.state[-1][-1]
        soc = E/E_max
        Voc = a0*np.exp(-a1*soc) + a2 + a3*soc - a4*soc**2 + a5*soc**3
        Rs  = b0*np.exp(-b1*soc) + b2 + b3*soc - b4*soc**2 + b5*soc**3
        Rts = c0*np.exp(-c1*soc) + c2
        Rtl = d0*np.exp(-d1*soc) + d2
        R   = Rs + Rts + Rtl

        I_cmax = 1000000*(E_max*soc_max - E)/N/(Voc*tdelta)
        I_dmax = 1000000*(E - E_max*soc_min)/N/(Voc*tdelta)
        p_cmax = N*(Voc*I_cmax + I_cmax**2*R)
        p_dmax = N*(Voc*I_dmax - I_dmax**2*R)

        P_cmax = p_cmax/1000000; P_dmax = p_dmax/1000000
        P_c = min(max(-action[0]*E_max, 0), P_max, P_cmax)
        P_d = min(max(action[0]*E_max,  0), P_max, P_dmax)
        p_c = 1000000*P_c/N; p_d = 1000000*P_d/N

        I_c = -(Voc - np.sqrt(Voc**2 + 4*R*p_c))/(2*R)
        I_d = (Voc - np.sqrt(Voc**2 - 4*R*p_d))/(2*R)
        if not np.isclose(p_c, 0):
            eff_c = (Voc*I_c)/p_c; eff_d = 1
            E_prime = E + eff_c*P_c*tdelta
            disp = -P_c
        elif not np.isclose(p_d, 0):
            eff_d = p_d/(Voc*I_d); eff_c = 1
            E_prime = E - (1/eff_d)*P_d*tdelta
            disp = P_d
        else:
            eff_c = 1; eff_d = 1
            E_prime = E
            disp = 0

        revenue = (imb*(P_d-P_c) - beta*(P_c+P_d))*tdelta

        next_state = self.state + [[imb, E_prime]]
        reward = (imb*(P_d-P_c) - beta*(P_c+P_d) - self.lagrange*abs(P_c-max(-action[0]*E_max,0)) - self.lagrange*abs(P_d-max(action[0]*E_max,0)))*tdelta
        done = False
        info = [E, -P_c, P_d, revenue]

        self.state = next_state
        return next_state, reward, done, info

# %%
def train_net(model, batch, optimizer):
    o, H, a, r, o_prime, H_prime, done = [], [], [], [], [], [], []
    for transition in batch[0]:
        o.append(transition[0])
        a.append(transition[1])
        r.append([transition[2]])
        o_prime.append(transition[3])
        done.append([0]) if transition[4] else done.append([1])
    for transition in batch[1]:
        H.append(transition[0])
        H_prime.append(transition[1])

    o         = torch.tensor(o,dtype=torch.float)
    H         = (H[0][0].detach(), H[0][1].detach())
    a         = torch.tensor(a,dtype=torch.float)
    r         = torch.tensor(r,dtype=torch.float)
    o_prime   = torch.tensor(o_prime,dtype=torch.float)
    H_prime   = (H_prime[0][0].detach(), H_prime[0][1].detach())
    done      = torch.tensor(done)

    pdf_old = torch.distributions.MultivariateNormal(model.pi(o, H)[0], var*torch.eye(out_size))
    prob_old = torch.exp(pdf_old.log_prob(a)).view(len(a),1)
    prob_old = prob_old.detach()

    v_target = r + gamma * model.v(o_prime, H_prime) * done
    td = r + gamma * model.v(o_prime, H_prime) * done - model.v(o, H)
    td = td.detach().numpy()
    advantage = []
    A = 0.0
    for delta in td[::-1].flatten():
        A = delta + gamma*lmbda*A
        advantage.append([A])
    advantage.reverse()
    advantage = torch.tensor(advantage, dtype=torch.float)

    for i in range(K_epoch):
        pdf = torch.distributions.MultivariateNormal(model.pi(o, H)[0], var*torch.eye(out_size))
        prob = torch.exp(pdf.log_prob(a)).view(len(a),1)
        ratio = torch.exp(torch.log(prob) - torch.log(prob_old))  # a/b == exp(log(a)-log(b))

        loss_actor = torch.min(ratio * advantage, torch.clamp(ratio, 1-eps_clip, 1+eps_clip) * advantage)
        loss_critic = F.mse_loss(model.v(o, H), v_target.detach())
        loss = -(loss_actor - C_value*loss_critic)

        optimizer.zero_grad()
        loss.mean().backward(retain_graph=True)
        optimizer.step()

# %%
model1 = LSTM()
env_train = Env(0.0, price_train)
env_val   = Env(0.0, price_val)
env_test  = Env(0.0, price_test)
bat_train, bat_val, bat_test = [], [], [] # SoC
cha_train, cha_val, cha_test = [], [], [] # Charging
dis_train, dis_val, dis_test = [], [], [] # Discharging
rev_train, rev_val, rev_test = [], [], [] # Revenue
total_episode = 10
max_iteration = int(len(data_train_csv)/T_horizon)
print_interval = 1

optimizer = torch.optim.Adam(model1.parameters(), lr=learning_rate)
REV_train_list = []; REV_val_list = []; REV_test_list = []
for n_epi in range(total_episode):
    bat_train += [[]]; bat_val += [[]]; bat_test += [[]]
    cha_train += [[]]; cha_val += [[]]; cha_test += [[]]
    dis_train += [[]]; dis_val += [[]]; dis_test += [[]]
    rev_train += [[]]; rev_val += [[]]; rev_test += [[]]

    state = env_train.reset()
    history = (torch.zeros([n_layers, 1, hidden_size], dtype=torch.float), torch.zeros([n_layers, 1, hidden_size], dtype=torch.float))
    for i in range(max_iteration):
        batch = [[],[]]
        for t in range(T_horizon):
            pi_out, next_history = model1.pi(torch.tensor(state[-1], dtype=torch.float), history)
            action = np.random.multivariate_normal(pi_out.detach().numpy()[0], var*np.identity(out_size), 1)[0].tolist()
            next_state, reward, done, info = env_train.step(action)

            batch[0].append((state[-1], action, reward, next_state[-1], done))
            batch[1].append((history, next_history))
            state = next_state[:]
            history = next_history

            bat = info[0]; cha = info[1]; dis = info[2]; revenue = info[3]
            bat_train[n_epi] += [bat]
            cha_train[n_epi] += [cha]
            dis_train[n_epi] += [dis]
            rev_train[n_epi] += [revenue]
            if done:
                break

        if n_epi != 0:
            train_net(model1, batch, optimizer)
        if done:
            break

    state = env_val.reset()
    history = (torch.zeros([n_layers, 1, hidden_size], dtype=torch.float), torch.zeros([n_layers, 1, hidden_size], dtype=torch.float))
    for k in range(len(env_val.data_imb)-1):
        pi_out, next_history = model1.pi(torch.tensor(state[-1], dtype=torch.float), history)
        action = pi_out[0].tolist()
        next_state, reward, done, info = env_val.step(action)

        state = next_state[:]
        history = next_history

        bat = info[0]; cha = info[1]; dis = info[2]; revenue = info[3]
        bat_val[n_epi] += [bat]
        cha_val[n_epi] += [cha]
        dis_val[n_epi] += [dis]
        rev_val[n_epi] += [revenue]

    state = env_test.reset()
    history = (torch.zeros([n_layers, 1, hidden_size], dtype=torch.float), torch.zeros([n_layers, 1, hidden_size], dtype=torch.float))
    for l in range(len(env_test.data_imb)-1):
        pi_out, next_history = model1.pi(torch.tensor(state[-1], dtype=torch.float), history)
        action = pi_out[0].tolist()
        next_state, reward, done, info = env_test.step(action)

        state = next_state[:]
        history = next_history

        bat = info[0]; cha = info[1]; dis = info[2]; revenue = info[3]
        bat_test[n_epi] += [bat]
        cha_test[n_epi] += [cha]
        dis_test[n_epi] += [dis]
        rev_test[n_epi] += [revenue]

    if (n_epi+1)%print_interval == 0:
        REV_train = round(max_price*100*np.mean(rev_train[n_epi]),3); REV_train_list += [REV_train]
        REV_val   = round(max_price*100*np.mean(rev_val[n_epi]),3); REV_val_list += [REV_val]
        REV_test  = round(max_price*100*np.mean(rev_test[n_epi]),3); REV_test_list += [REV_test]

        print("episode: {}".format(n_epi+1))
        print("REV_train: ${}".format(REV_train).ljust(25), end="")
        print("REV_val: ${}".format(REV_val).ljust(25), end="")
        print("REV_test: ${}".format(REV_test).ljust(25))
        print("------------------------------------------------------------------------------------------")

    if REV_val_list[-1] == np.max(REV_val_list):
        torch.save(model1.state_dict(), 'MODEL1.pt')
# Out:
# episode: 1
# REV_train: $-4.427       REV_val: $-4.057         REV_test: $-4.906
# ------------------------------------------------------------------------------------------
# episode: 2
# REV_train: $-4.232       REV_val: $-2.746         REV_test: $-2.745
# ------------------------------------------------------------------------------------------
# episode: 3
# REV_train: $0.379        REV_val: $3.89           REV_test: $4.805
# ------------------------------------------------------------------------------------------
# episode: 4
# REV_train: $0.047        REV_val: $3.916          REV_test: $5.167
# ------------------------------------------------------------------------------------------
# episode: 5
# REV_train: $0.745        REV_val: $3.923          REV_test: $5.196
# ------------------------------------------------------------------------------------------
# episode: 6
# REV_train: $1.616        REV_val: $3.945          REV_test: $5.369
# ------------------------------------------------------------------------------------------
# episode: 7
# REV_train: $1.878        REV_val: $3.912          REV_test: $5.35
# ------------------------------------------------------------------------------------------
# episode: 8
# REV_train: $1.671        REV_val: $3.923          REV_test: $5.373
# ------------------------------------------------------------------------------------------
# episode: 9
# REV_train: $1.844        REV_val: $3.731          REV_test: $5.201
# ------------------------------------------------------------------------------------------
# episode: 10
# REV_train: $1.952        REV_val: $3.712          REV_test: $5.063
# ------------------------------------------------------------------------------------------

# %%
model1_test = LSTM()
model1_test.load_state_dict(torch.load('MODEL1.pt'))

bat_val = []; bat_test = []
cha_val = []; cha_test = []
dis_val = []; dis_test = []
rev_val = []; rev_test = []

state = env_val.reset()
history = (torch.zeros([n_layers, 1, hidden_size], dtype=torch.float), torch.zeros([n_layers, 1, hidden_size], dtype=torch.float))
for k in range(len(env_val.data_imb)-1):
    pi_out, next_history = model1_test.pi(torch.tensor(state[-1], dtype=torch.float), history)
    action = pi_out[0].tolist()
    next_state, reward, done, info = env_val.step(action)

    state = next_state[:]
    history = next_history

    bat = info[0]; cha = info[1]; dis = info[2]; revenue = info[3]
    bat_val += [bat]
    cha_val += [cha]
    dis_val += [dis]
    rev_val += [revenue]

state = env_test.reset()
history = (torch.zeros([n_layers, 1, hidden_size], dtype=torch.float), torch.zeros([n_layers, 1, hidden_size], dtype=torch.float))
for l in range(len(env_test.data_imb)-1):
    pi_out, next_history = model1_test.pi(torch.tensor(state[-1], dtype=torch.float), history)
    action = pi_out[0].tolist()
    next_state, reward, done, info = env_test.step(action)

    state = next_state[:]
    history = next_history

    bat = info[0]; cha = info[1]; dis = info[2]; revenue = info[3]
    bat_test += [bat]
    cha_test += [cha]
    dis_test += [dis]
    rev_test += [revenue]

REV_val   = round(max_price*100*np.mean(rev_val),3)
REV_test  = round(max_price*100*np.mean(rev_test),3)
print("REV_val: ${}".format(REV_val).ljust(25), end="")
print("REV_test: ${}".format(REV_test).ljust(25))
print("------------------------------------------------------------------------------------------")

plt.plot(bat_test)
# Out:
# <ipython-input-8-72dd19740c1e>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model1_test.load_state_dict(torch.load('MODEL1.pt'))
# REV_val: $3.945          REV_test: $5.369
# ------------------------------------------------------------------------------------------

# %%
model2 = LSTM()
model2.load_state_dict(torch.load('MODEL2_pre.pt'))
env_train = Env(1.0, price_train)
env_val   = Env(1.0, price_val)
env_test  = Env(1.0, price_test)
bat_train, bat_val, bat_test = [], [], [] # SoC
cha_train, cha_val, cha_test = [], [], [] # Charging
dis_train, dis_val, dis_test = [], [], [] # Discharging
rev_train, rev_val, rev_test = [], [], [] # Revenue
total_episode = 100
max_iteration = int(len(data_train_csv)/T_horizon)
print_interval = 1

optimizer = torch.optim.Adam(model2.parameters(), lr=learning_rate)
REV_train_list = []; REV_val_list = []; REV_test_list = []
for n_epi in range(total_episode):
    bat_train += [[]]; bat_val += [[]]; bat_test += [[]]
    cha_train += [[]]; cha_val += [[]]; cha_test += [[]]
    dis_train += [[]]; dis_val += [[]]; dis_test += [[]]
    rev_train += [[]]; rev_val += [[]]; rev_test += [[]]

    state = env_train.reset()
    history = (torch.zeros([n_layers, 1, hidden_size], dtype=torch.float), torch.zeros([n_layers, 1, hidden_size], dtype=torch.float))
    for i in range(max_iteration):
        batch = [[],[]]
        for t in range(T_horizon):
            pi_out, next_history = model2.pi(torch.tensor(state[-1], dtype=torch.float), history)
            action = np.random.multivariate_normal(pi_out.detach().numpy()[0], var*np.identity(out_size), 1)[0].tolist()
            next_state, reward, done, info = env_train.step(action)

            batch[0].append((state[-1], action, reward, next_state[-1], done))
            batch[1].append((history, next_history))
            state = next_state[:]
            history = next_history

            bat = info[0]; cha = info[1]; dis = info[2]; revenue = info[3]
            bat_train[n_epi] += [bat]
            cha_train[n_epi] += [cha]
            dis_train[n_epi] += [dis]
            rev_train[n_epi] += [revenue]
            if done:
                break

        if n_epi != 0:
            train_net(model2, batch, optimizer)
        if done:
            break

    state = env_val.reset()
    history = (torch.zeros([n_layers, 1, hidden_size], dtype=torch.float), torch.zeros([n_layers, 1, hidden_size], dtype=torch.float))
    for k in range(len(env_val.data_imb)-1):
        pi_out, next_history = model2.pi(torch.tensor(state[-1], dtype=torch.float), history)
        action = pi_out[0].tolist()
        next_state, reward, done, info = env_val.step(action)

        state = next_state[:]
        history = next_history

        bat = info[0]; cha = info[1]; dis = info[2]; revenue = info[3]
        bat_val[n_epi] += [bat]
        cha_val[n_epi] += [cha]
        dis_val[n_epi] += [dis]
        rev_val[n_epi] += [revenue]

    state = env_test.reset()
    history = (torch.zeros([n_layers, 1, hidden_size], dtype=torch.float), torch.zeros([n_layers, 1, hidden_size], dtype=torch.float))
    for l in range(len(env_test.data_imb)-1):
        pi_out, next_history = model2.pi(torch.tensor(state[-1], dtype=torch.float), history)
        action = pi_out[0].tolist()
        next_state, reward, done, info = env_test.step(action)

        state = next_state[:]
        history = next_history

        bat = info[0]; cha = info[1]; dis = info[2]; revenue = info[3]
        bat_test[n_epi] += [bat]
        cha_test[n_epi] += [cha]
        dis_test[n_epi] += [dis]
        rev_test[n_epi] += [revenue]

    if (n_epi+1)%print_interval == 0:
        REV_train = round(max_price*100*np.mean(rev_train[n_epi]),3); REV_train_list += [REV_train]
        REV_val   = round(max_price*100*np.mean(rev_val[n_epi]),3); REV_val_list += [REV_val]
        REV_test  = round(max_price*100*np.mean(rev_test[n_epi]),3); REV_test_list += [REV_test]

        print("episode: {}".format(n_epi+1))
        print("REV_train: ${}".format(REV_train).ljust(25), end="")
        print("REV_val: ${}".format(REV_val).ljust(25), end="")
        print("REV_test: ${}".format(REV_test).ljust(25))
        print("------------------------------------------------------------------------------------------")

    if REV_val_list[-1] == np.max(REV_val_list):
        torch.save(model2.state_dict(), 'MODEL2.pt')
# Out:
# <ipython-input-13-19d61f937192>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model2.load_state_dict(torch.load('MODEL2_pre.pt'))
# episode: 1
# REV_train: $5.969        REV_val: $20.937         REV_test: $11.514
# ------------------------------------------------------------------------------------------
# episode: 2
# REV_train: $11.933       REV_val: $26.615         REV_test: $13.11
# ------------------------------------------------------------------------------------------
# episode: 3
# REV_train: $15.297       REV_val: $25.72          REV_test: $13.068
# ------------------------------------------------------------------------------------------
# episode: 4
# REV_train: $13.927       REV_val: $25.003         REV_test: $12.04
# ------------------------------------------------------------------------------------------
# episode: 5
# REV_train: $9.68         REV_val: $21.007         REV_test: $11.216
# ------------------------------------------------------------------------------------------
# episode: 6
# REV_train: $8.735        REV_val: $16.886         REV_test: $10.322
# ------------------------------------------------------------------------------------------
# episode: 7
# REV_train: $6.823        REV_val: $14.474         REV_test: $9.319
# ------------------------------------------------------------------------------------------
# episode: 8
# REV_train: $7.068        REV_val: $15.221         REV_test: $9.586
# ------------------------------------------------------------------------------------------
# episode: 9
# REV_train: $4.955        REV_val: $14.746         REV_test: $9.822
# ------------------------------------------------------------------------------------------
# episode: 10
# REV_train: $7.928        REV_val: $18.246         REV_test: $10.717
# ------------------------------------------------------------------------------------------
# episode: 11
# REV_train: $10.711       REV_val: $21.433         REV_test: $11.514
# ------------------------------------------------------------------------------------------
# episode: 12
# REV_train: $9.67         REV_val: $20.617         REV_test: $10.704
# ------------------------------------------------------------------------------------------
# episode: 13
# REV_train: $12.105       REV_val: $21.167         REV_test: $9.124
# ------------------------------------------------------------------------------------------
# episode: 14
# REV_train: $8.215        REV_val: $15.038         REV_test: $7.356
# ------------------------------------------------------------------------------------------
# episode: 15
# REV_train: $7.946        REV_val: $15.728         REV_test: $7.805
# ------------------------------------------------------------------------------------------
# episode: 16
# REV_train: $5.527        REV_val: $15.225         REV_test: $8.423
# ------------------------------------------------------------------------------------------
# episode: 17
# REV_train: $6.228        REV_val: $15.69          REV_test: $8.361
# ------------------------------------------------------------------------------------------
# episode: 18
# REV_train: $5.27         REV_val: $12.309         REV_test: $7.736
# ------------------------------------------------------------------------------------------
# episode: 19
# REV_train: $5.469        REV_val: $12.694         REV_test: $7.866
# ------------------------------------------------------------------------------------------
# episode: 20
# REV_train: $3.532        REV_val: $10.548         REV_test: $7.281
# ------------------------------------------------------------------------------------------
# episode: 21
# REV_train: $2.052        REV_val: $9.596          REV_test: $6.867
# ------------------------------------------------------------------------------------------
# episode: 22
# REV_train: $0.455        REV_val: $10.216         REV_test: $6.955
# ------------------------------------------------------------------------------------------
# episode: 23
# REV_train: $3.445        REV_val: $12.021         REV_test: $7.523
# ------------------------------------------------------------------------------------------
# episode: 24
# REV_train: $3.934        REV_val: $13.387         REV_test: $7.884
# ------------------------------------------------------------------------------------------
# episode: 25
# REV_train: $5.587        REV_val: $16.533         REV_test: $8.897
# ------------------------------------------------------------------------------------------
# episode: 26
# REV_train: $6.923        REV_val: $20.228         REV_test: $10.137
# ------------------------------------------------------------------------------------------
# episode: 27
# REV_train: $12.431       REV_val: $25.909         REV_test: $12.023
# ------------------------------------------------------------------------------------------
# episode: 28
# REV_train: $11.825       REV_val: $27.808         REV_test: $12.798
# ------------------------------------------------------------------------------------------
# episode: 29
# REV_train: $11.631       REV_val: $25.506         REV_test: $12.22
# ------------------------------------------------------------------------------------------
# episode: 30
# REV_train: $12.919       REV_val: $23.089         REV_test: $11.268
# ------------------------------------------------------------------------------------------
# episode: 31
# REV_train: $10.291       REV_val: $22.851         REV_test: $11.594
# ------------------------------------------------------------------------------------------
# episode: 32
# REV_train: $9.503        REV_val: $22.122         REV_test: $11.361
# ------------------------------------------------------------------------------------------
# episode: 33
# REV_train: $10.775       REV_val: $23.69          REV_test: $12.012
# ------------------------------------------------------------------------------------------
# episode: 34
# REV_train: $15.998       REV_val: $30.035         REV_test: $14.569
# ------------------------------------------------------------------------------------------
# episode: 35
# REV_train: $13.078       REV_val: $27.166         REV_test: $12.732
# ------------------------------------------------------------------------------------------
# episode: 36
# REV_train: $13.446       REV_val: $22.868         REV_test: $12.513
# ------------------------------------------------------------------------------------------
# episode: 37
# REV_train: $10.254       REV_val: $21.562         REV_test: $10.975
# ------------------------------------------------------------------------------------------
# episode: 38
# REV_train: $12.375       REV_val: $25.536         REV_test: $11.569
# ------------------------------------------------------------------------------------------
# episode: 39
# REV_train: $12.976       REV_val: $20.543         REV_test: $11.12
# ------------------------------------------------------------------------------------------
# episode: 40
# REV_train: $10.108       REV_val: $13.915         REV_test: $9.049
# ------------------------------------------------------------------------------------------
# episode: 41
# REV_train: $7.521        REV_val: $9.925          REV_test: $7.717
# ------------------------------------------------------------------------------------------
# episode: 42
# REV_train: $-0.839       REV_val: $8.617          REV_test: $7.111
# ------------------------------------------------------------------------------------------
# episode: 43
# REV_train: $0.94         REV_val: $11.199         REV_test: $7.788
# ------------------------------------------------------------------------------------------
# episode: 44
# REV_train: $1.669        REV_val: $9.884          REV_test: $7.488
# ------------------------------------------------------------------------------------------
# episode: 45
# REV_train: $2.204        REV_val: $11.264         REV_test: $7.702
# ------------------------------------------------------------------------------------------
# episode: 46
# REV_train: $1.449        REV_val: $11.7           REV_test: $7.929
# ------------------------------------------------------------------------------------------
# episode: 47
# REV_train: $3.992        REV_val: $14.975         REV_test: $8.938
# ------------------------------------------------------------------------------------------
# episode: 48
# REV_train: $9.252        REV_val: $15.609         REV_test: $9.74
# ------------------------------------------------------------------------------------------
# episode: 49
# REV_train: $7.782        REV_val: $15.482         REV_test: $9.858
# ------------------------------------------------------------------------------------------
# episode: 50
# REV_train: $6.703        REV_val: $16.415         REV_test: $9.76
# ------------------------------------------------------------------------------------------
# episode: 51
# REV_train: $11.281       REV_val: $18.43          REV_test: $10.405
# ------------------------------------------------------------------------------------------
# episode: 52
# REV_train: $6.185        REV_val: $13.927         REV_test: $9.292
# ------------------------------------------------------------------------------------------
# episode: 53
# REV_train: $5.125        REV_val: $13.886         REV_test: $8.846
# ------------------------------------------------------------------------------------------
# episode: 54
# REV_train: $7.86         REV_val: $15.88          REV_test: $9.577
# ------------------------------------------------------------------------------------------
# episode: 55
# REV_train: $9.887        REV_val: $15.209         REV_test: $9.737
# ------------------------------------------------------------------------------------------
# episode: 56
# REV_train: $9.838        REV_val: $20.032         REV_test: $11.392
# ------------------------------------------------------------------------------------------
# episode: 57
# REV_train: $9.462        REV_val: $19.454         REV_test: $11.552
# ------------------------------------------------------------------------------------------
# episode: 58
# REV_train: $8.83         REV_val: $17.176         REV_test: $10.592
# ------------------------------------------------------------------------------------------
# episode: 59
# REV_train: $5.372        REV_val: $17.468         REV_test: $10.301
# ------------------------------------------------------------------------------------------
# episode: 60
# REV_train: $9.528        REV_val: $16.295         REV_test: $10.348
# ------------------------------------------------------------------------------------------
# episode: 61
# REV_train: $9.125        REV_val: $13.469         REV_test: $9.729
# ------------------------------------------------------------------------------------------
# episode: 62
# REV_train: $5.847        REV_val: $12.025         REV_test: $8.984
# ------------------------------------------------------------------------------------------
# episode: 63
# REV_train: $0.649        REV_val: $10.03          REV_test: $8.054
# ------------------------------------------------------------------------------------------
# episode: 64
# REV_train: $0.056        REV_val: $10.951         REV_test: $8.246
# ------------------------------------------------------------------------------------------
# episode: 65
# REV_train: $4.239        REV_val: $9.549          REV_test: $7.721
# ------------------------------------------------------------------------------------------
# episode: 66
# REV_train: $-0.199       REV_val: $7.716          REV_test: $6.935
# ------------------------------------------------------------------------------------------
# episode: 67
# REV_train: $1.577        REV_val: $7.833          REV_test: $6.934
# ------------------------------------------------------------------------------------------
# episode: 68
# REV_train: $-0.606       REV_val: $8.061          REV_test: $7.079
# ------------------------------------------------------------------------------------------
# episode: 69
# REV_train: $2.879        REV_val: $8.784          REV_test: $7.507
# ------------------------------------------------------------------------------------------
# episode: 70
# REV_train: $2.025        REV_val: $9.598          REV_test: $7.797
# ------------------------------------------------------------------------------------------
# episode: 71
# REV_train: $1.821        REV_val: $12.116         REV_test: $9.076
# ------------------------------------------------------------------------------------------
# episode: 72
# REV_train: $1.654        REV_val: $14.519         REV_test: $10.416
# ------------------------------------------------------------------------------------------
# episode: 73
# REV_train: $4.35         REV_val: $9.769          REV_test: $8.057
# ------------------------------------------------------------------------------------------
# episode: 74
# REV_train: $2.287        REV_val: $7.709          REV_test: $6.827
# ------------------------------------------------------------------------------------------
# episode: 75
# REV_train: $5.0          REV_val: $11.324         REV_test: $8.629
# ------------------------------------------------------------------------------------------
# episode: 76
# REV_train: $4.148        REV_val: $10.93          REV_test: $8.512
# ------------------------------------------------------------------------------------------
# episode: 77
# REV_train: $4.16         REV_val: $17.569         REV_test: $11.695
# ------------------------------------------------------------------------------------------
# episode: 78
# REV_train: $9.358        REV_val: $17.044         REV_test: $11.619
# ------------------------------------------------------------------------------------------
# episode: 79
# REV_train: $7.152        REV_val: $14.189         REV_test: $10.251
# ------------------------------------------------------------------------------------------
# episode: 80
# REV_train: $7.637        REV_val: $15.731         REV_test: $10.828
# ------------------------------------------------------------------------------------------
# episode: 81
# REV_train: $3.847        REV_val: $15.902         REV_test: $10.977
# ------------------------------------------------------------------------------------------
# episode: 82
# REV_train: $6.645        REV_val: $17.78          REV_test: $11.851
# ------------------------------------------------------------------------------------------
# episode: 83
# REV_train: $9.452        REV_val: $17.147         REV_test: $11.649
# ------------------------------------------------------------------------------------------
# episode: 84
# REV_train: $7.438        REV_val: $15.255         REV_test: $10.747
# ------------------------------------------------------------------------------------------
# episode: 85
# REV_train: $12.174       REV_val: $19.377         REV_test: $12.563
# ------------------------------------------------------------------------------------------
# episode: 86
# REV_train: $9.14         REV_val: $20.624         REV_test: $13.462
# ------------------------------------------------------------------------------------------
# episode: 87
# REV_train: $11.947       REV_val: $21.636         REV_test: $14.257
# ------------------------------------------------------------------------------------------
# episode: 88
# REV_train: $12.61        REV_val: $22.796         REV_test: $14.99
# ------------------------------------------------------------------------------------------
# episode: 89
# REV_train: $13.171       REV_val: $19.955         REV_test: $13.455
# ------------------------------------------------------------------------------------------
# episode: 90
# REV_train: $9.954        REV_val: $12.267         REV_test: $9.468
# ------------------------------------------------------------------------------------------
# episode: 91
# REV_train: $9.707        REV_val: $16.022         REV_test: $11.439
# ------------------------------------------------------------------------------------------
# episode: 92
# REV_train: $7.658        REV_val: $15.842         REV_test: $11.589
# ------------------------------------------------------------------------------------------
# episode: 93
# REV_train: $8.484        REV_val: $15.378         REV_test: $11.433
# ------------------------------------------------------------------------------------------
# episode: 94
# REV_train: $8.434        REV_val: $17.015         REV_test: $12.345
# ------------------------------------------------------------------------------------------
# episode: 95
# REV_train: $8.294        REV_val: $16.789         REV_test: $12.536
# ------------------------------------------------------------------------------------------
# episode: 96
# REV_train: $9.98         REV_val: $18.313         REV_test: $13.345
# ------------------------------------------------------------------------------------------
# episode: 97
# REV_train: $11.328       REV_val: $17.924         REV_test: $13.163
# ------------------------------------------------------------------------------------------
# episode: 98
# REV_train: $11.657       REV_val: $16.778         REV_test: $12.354
# ------------------------------------------------------------------------------------------
# episode: 99
# REV_train: $8.045        REV_val: $16.146         REV_test: $11.695
# ------------------------------------------------------------------------------------------
# episode: 100
# REV_train: $8.423        REV_val: $15.911         REV_test: $11.786
# ------------------------------------------------------------------------------------------

# %%
model2_test = LSTM()
model2_test.load_state_dict(torch.load('MODEL2.pt'))

bat_val = []; bat_test = []
cha_val = []; cha_test = []
dis_val = []; dis_test = []
rev_val = []; rev_test = []

state = env_val.reset()
history = (torch.zeros([n_layers, 1, hidden_size], dtype=torch.float), torch.zeros([n_layers, 1, hidden_size], dtype=torch.float))
for k in range(len(env_val.data_imb)-1):
    pi_out, next_history = model2_test.pi(torch.tensor(state[-1], dtype=torch.float), history)
    action = pi_out[0].tolist()
    next_state, reward, done, info = env_val.step(action)

    state = next_state[:]
    history = next_history

    bat = info[0]; cha = info[1]; dis = info[2]; revenue = info[3]
    bat_val += [bat]
    cha_val += [cha]
    dis_val += [dis]
    rev_val += [revenue]

state = env_test.reset()
history = (torch.zeros([n_layers, 1, hidden_size], dtype=torch.float), torch.zeros([n_layers, 1, hidden_size], dtype=torch.float))
for l in range(len(env_test.data_imb)-1):
    pi_out, next_history = model2_test.pi(torch.tensor(state[-1], dtype=torch.float), history)
    action = pi_out[0].tolist()
    next_state, reward, done, info = env_test.step(action)

    state = next_state[:]
    history = next_history

    bat = info[0]; cha = info[1]; dis = info[2]; revenue = info[3]
    bat_test += [bat]
    cha_test += [cha]
    dis_test += [dis]
    rev_test += [revenue]

REV_val   = round(max_price*100*np.mean(rev_val),3)
REV_test  = round(max_price*100*np.mean(rev_test),3)
print("REV_val: ${}".format(REV_val).ljust(25), end="")
print("REV_test: ${}".format(REV_test).ljust(25))
print("------------------------------------------------------------------------------------------")

plt.plot(bat_test)
# Out:
# <ipython-input-14-f754b0b23b3b>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model2_test.load_state_dict(torch.load('MODEL2.pt'))
# REV_val: $30.035         REV_test: $14.569
# ------------------------------------------------------------------------------------------

# %%
model3 = LSTM()
model3.load_state_dict(torch.load('MODEL2_pre.pt'))
env_train = Env(0.1, price_train)
env_val   = Env(0.1, price_val)
env_test  = Env(0.1, price_test)
bat_train, bat_val, bat_test = [], [], [] # SoC
cha_train, cha_val, cha_test = [], [], [] # Charging
dis_train, dis_val, dis_test = [], [], [] # Discharging
rev_train, rev_val, rev_test = [], [], [] # Revenue
total_episode = 100
max_iteration = int(len(data_train_csv)/T_horizon)
print_interval = 1

optimizer = torch.optim.Adam(model3.parameters(), lr=learning_rate)
REV_train_list = []; REV_val_list = []; REV_test_list = []
for n_epi in range(total_episode):
    bat_train += [[]]; bat_val += [[]]; bat_test += [[]]
    cha_train += [[]]; cha_val += [[]]; cha_test += [[]]
    dis_train += [[]]; dis_val += [[]]; dis_test += [[]]
    rev_train += [[]]; rev_val += [[]]; rev_test += [[]]

    state = env_train.reset()
    history = (torch.zeros([n_layers, 1, hidden_size], dtype=torch.float), torch.zeros([n_layers, 1, hidden_size], dtype=torch.float))
    for i in range(max_iteration):
        batch = [[],[]]
        for t in range(T_horizon):
            pi_out, next_history = model3.pi(torch.tensor(state[-1], dtype=torch.float), history)
            action = np.random.multivariate_normal(pi_out.detach().numpy()[0], var*np.identity(out_size), 1)[0].tolist()
            next_state, reward, done, info = env_train.step(action)

            batch[0].append((state[-1], action, reward, next_state[-1], done))
            batch[1].append((history, next_history))
            state = next_state[:]
            history = next_history

            bat = info[0]; cha = info[1]; dis = info[2]; revenue = info[3]
            bat_train[n_epi] += [bat]
            cha_train[n_epi] += [cha]
            dis_train[n_epi] += [dis]
            rev_train[n_epi] += [revenue]
            if done:
                break

        if n_epi != 0:
            train_net(model3, batch, optimizer)
        if done:
            break

    state = env_val.reset()
    history = (torch.zeros([n_layers, 1, hidden_size], dtype=torch.float), torch.zeros([n_layers, 1, hidden_size], dtype=torch.float))
    for k in range(len(env_val.data_imb)-1):
        pi_out, next_history = model3.pi(torch.tensor(state[-1], dtype=torch.float), history)
        action = pi_out[0].tolist()
        next_state, reward, done, info = env_val.step(action)

        state = next_state[:]
        history = next_history

        bat = info[0]; cha = info[1]; dis = info[2]; revenue = info[3]
        bat_val[n_epi] += [bat]
        cha_val[n_epi] += [cha]
        dis_val[n_epi] += [dis]
        rev_val[n_epi] += [revenue]

    state = env_test.reset()
    history = (torch.zeros([n_layers, 1, hidden_size], dtype=torch.float), torch.zeros([n_layers, 1, hidden_size], dtype=torch.float))
    for l in range(len(env_test.data_imb)-1):
        pi_out, next_history = model3.pi(torch.tensor(state[-1], dtype=torch.float), history)
        action = pi_out[0].tolist()
        next_state, reward, done, info = env_test.step(action)

        state = next_state[:]
        history = next_history

        bat = info[0]; cha = info[1]; dis = info[2]; revenue = info[3]
        bat_test[n_epi] += [bat]
        cha_test[n_epi] += [cha]
        dis_test[n_epi] += [dis]
        rev_test[n_epi] += [revenue]

    if (n_epi+1)%print_interval == 0:
        REV_train = round(max_price*100*np.mean(rev_train[n_epi]),3); REV_train_list += [REV_train]
        REV_val   = round(max_price*100*np.mean(rev_val[n_epi]),3); REV_val_list += [REV_val]
        REV_test  = round(max_price*100*np.mean(rev_test[n_epi]),3); REV_test_list += [REV_test]

        print("episode: {}".format(n_epi+1))
        print("REV_train: ${}".format(REV_train).ljust(25), end="")
        print("REV_val: ${}".format(REV_val).ljust(25), end="")
        print("REV_test: ${}".format(REV_test).ljust(25))
        print("------------------------------------------------------------------------------------------")

    if REV_val_list[-1] == np.max(REV_val_list):
        torch.save(model3.state_dict(), 'MODEL3.pt')
# Out:
# <ipython-input-11-8411eb8521ba>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model3.load_state_dict(torch.load('MODEL2_pre.pt'))
# episode: 1
# REV_train: $11.602       REV_val: $20.937         REV_test: $11.514
# ------------------------------------------------------------------------------------------
# episode: 2
# REV_train: $10.247       REV_val: $22.945         REV_test: $12.392
# ------------------------------------------------------------------------------------------
# episode: 3
# REV_train: $10.769       REV_val: $23.017         REV_test: $12.509
# ------------------------------------------------------------------------------------------
# episode: 4
# REV_train: $10.54        REV_val: $23.843         REV_test: $13.943
# ------------------------------------------------------------------------------------------
# episode: 5
# REV_train: $12.07        REV_val: $21.979         REV_test: $13.302
# ------------------------------------------------------------------------------------------
# episode: 6
# REV_train: $14.343       REV_val: $24.106         REV_test: $12.781
# ------------------------------------------------------------------------------------------
# episode: 7
# REV_train: $14.822       REV_val: $29.609         REV_test: $14.306
# ------------------------------------------------------------------------------------------
# episode: 8
# REV_train: $17.176       REV_val: $28.407         REV_test: $11.844
# ------------------------------------------------------------------------------------------
# episode: 9
# REV_train: $14.743       REV_val: $27.244         REV_test: $11.915
# ------------------------------------------------------------------------------------------
# episode: 10
# REV_train: $13.525       REV_val: $26.9           REV_test: $13.746
# ------------------------------------------------------------------------------------------
# episode: 11
# REV_train: $16.701       REV_val: $29.32          REV_test: $12.215
# ------------------------------------------------------------------------------------------
# episode: 12
# REV_train: $16.887       REV_val: $31.757         REV_test: $13.925
# ------------------------------------------------------------------------------------------
# episode: 13
# REV_train: $15.142       REV_val: $29.777         REV_test: $13.349
# ------------------------------------------------------------------------------------------
# episode: 14
# REV_train: $16.25        REV_val: $26.774         REV_test: $12.061
# ------------------------------------------------------------------------------------------
# episode: 15
# REV_train: $13.526       REV_val: $27.783         REV_test: $13.685
# ------------------------------------------------------------------------------------------
# episode: 16
# REV_train: $12.555       REV_val: $26.328         REV_test: $13.744
# ------------------------------------------------------------------------------------------
# episode: 17
# REV_train: $15.133       REV_val: $25.911         REV_test: $11.199
# ------------------------------------------------------------------------------------------
# episode: 18
# REV_train: $11.668       REV_val: $25.809         REV_test: $10.519
# ------------------------------------------------------------------------------------------
# episode: 19
# REV_train: $9.952        REV_val: $24.519         REV_test: $9.852
# ------------------------------------------------------------------------------------------
# episode: 20
# REV_train: $10.296       REV_val: $19.343         REV_test: $9.825
# ------------------------------------------------------------------------------------------
# episode: 21
# REV_train: $5.882        REV_val: $11.448         REV_test: $8.981
# ------------------------------------------------------------------------------------------
# episode: 22
# REV_train: $1.779        REV_val: $6.665          REV_test: $7.189
# ------------------------------------------------------------------------------------------
# episode: 23
# REV_train: $3.744        REV_val: $11.09          REV_test: $8.503
# ------------------------------------------------------------------------------------------
# episode: 24
# REV_train: $1.882        REV_val: $9.327          REV_test: $7.958
# ------------------------------------------------------------------------------------------
# episode: 25
# REV_train: $1.323        REV_val: $13.544         REV_test: $8.206
# ------------------------------------------------------------------------------------------
# episode: 26
# REV_train: $2.624        REV_val: $13.55          REV_test: $8.243
# ------------------------------------------------------------------------------------------
# episode: 27
# REV_train: $1.347        REV_val: $16.714         REV_test: $9.043
# ------------------------------------------------------------------------------------------
# episode: 28
# REV_train: $6.074        REV_val: $18.673         REV_test: $10.058
# ------------------------------------------------------------------------------------------
# episode: 29
# REV_train: $8.82         REV_val: $20.915         REV_test: $10.764
# ------------------------------------------------------------------------------------------
# episode: 30
# REV_train: $10.003       REV_val: $22.416         REV_test: $11.565
# ------------------------------------------------------------------------------------------
# episode: 31
# REV_train: $13.461       REV_val: $26.916         REV_test: $12.352
# ------------------------------------------------------------------------------------------
# episode: 32
# REV_train: $16.352       REV_val: $28.264         REV_test: $12.073
# ------------------------------------------------------------------------------------------
# episode: 33
# REV_train: $15.044       REV_val: $27.207         REV_test: $13.858
# ------------------------------------------------------------------------------------------
# episode: 34
# REV_train: $14.903       REV_val: $24.326         REV_test: $14.711
# ------------------------------------------------------------------------------------------
# episode: 35
# REV_train: $12.866       REV_val: $24.712         REV_test: $14.271
# ------------------------------------------------------------------------------------------
# episode: 36
# REV_train: $10.469       REV_val: $20.459         REV_test: $12.313
# ------------------------------------------------------------------------------------------
# episode: 37
# REV_train: $10.573       REV_val: $21.406         REV_test: $12.612
# ------------------------------------------------------------------------------------------
# episode: 38
# REV_train: $6.838        REV_val: $19.231         REV_test: $11.478
# ------------------------------------------------------------------------------------------
# episode: 39
# REV_train: $7.227        REV_val: $16.104         REV_test: $10.333
# ------------------------------------------------------------------------------------------
# episode: 40
# REV_train: $8.618        REV_val: $18.814         REV_test: $11.063
# ------------------------------------------------------------------------------------------
# episode: 41
# REV_train: $8.272        REV_val: $14.531         REV_test: $9.926
# ------------------------------------------------------------------------------------------
# episode: 42
# REV_train: $5.932        REV_val: $17.016         REV_test: $10.652
# ------------------------------------------------------------------------------------------
# episode: 43
# REV_train: $9.252        REV_val: $21.308         REV_test: $12.79
# ------------------------------------------------------------------------------------------
# episode: 44
# REV_train: $12.184       REV_val: $23.776         REV_test: $13.539
# ------------------------------------------------------------------------------------------
# episode: 45
# REV_train: $12.093       REV_val: $23.327         REV_test: $13.545
# ------------------------------------------------------------------------------------------
# episode: 46
# REV_train: $10.284       REV_val: $26.987         REV_test: $15.066
# ------------------------------------------------------------------------------------------
# episode: 47
# REV_train: $15.101       REV_val: $29.026         REV_test: $17.275
# ------------------------------------------------------------------------------------------
# episode: 48
# REV_train: $17.115       REV_val: $26.272         REV_test: $16.717
# ------------------------------------------------------------------------------------------
# episode: 49
# REV_train: $14.314       REV_val: $18.141         REV_test: $13.561
# ------------------------------------------------------------------------------------------
# episode: 50
# REV_train: $12.858       REV_val: $20.843         REV_test: $14.613
# ------------------------------------------------------------------------------------------
# episode: 51
# REV_train: $11.415       REV_val: $23.93          REV_test: $16.055
# ------------------------------------------------------------------------------------------
# episode: 52
# REV_train: $11.555       REV_val: $23.457         REV_test: $15.465
# ------------------------------------------------------------------------------------------
# episode: 53
# REV_train: $12.636       REV_val: $21.441         REV_test: $14.435
# ------------------------------------------------------------------------------------------
# episode: 54
# REV_train: $11.536       REV_val: $21.863         REV_test: $14.589
# ------------------------------------------------------------------------------------------
# episode: 55
# REV_train: $14.383       REV_val: $22.461         REV_test: $14.693
# ------------------------------------------------------------------------------------------
# episode: 56
# REV_train: $13.907       REV_val: $24.737         REV_test: $15.759
# ------------------------------------------------------------------------------------------
# episode: 57
# REV_train: $18.1         REV_val: $27.224         REV_test: $16.951
# ------------------------------------------------------------------------------------------
# episode: 58
# REV_train: $14.31        REV_val: $25.339         REV_test: $16.671
# ------------------------------------------------------------------------------------------
# episode: 59
# REV_train: $16.396       REV_val: $25.966         REV_test: $17.384
# ------------------------------------------------------------------------------------------
# episode: 60
# REV_train: $17.71        REV_val: $24.868         REV_test: $16.337
# ------------------------------------------------------------------------------------------
# episode: 61
# REV_train: $16.258       REV_val: $29.122         REV_test: $17.693
# ------------------------------------------------------------------------------------------
# episode: 62
# REV_train: $22.119       REV_val: $33.899         REV_test: $20.193
# ------------------------------------------------------------------------------------------
# episode: 63
# REV_train: $18.97        REV_val: $31.321         REV_test: $19.484
# ------------------------------------------------------------------------------------------
# episode: 64
# REV_train: $19.488       REV_val: $31.817         REV_test: $19.771
# ------------------------------------------------------------------------------------------
# episode: 65
# REV_train: $15.976       REV_val: $27.462         REV_test: $17.585
# ------------------------------------------------------------------------------------------
# episode: 66
# REV_train: $18.456       REV_val: $31.185         REV_test: $19.345
# ------------------------------------------------------------------------------------------
# episode: 67
# REV_train: $19.181       REV_val: $28.985         REV_test: $18.438
# ------------------------------------------------------------------------------------------
# episode: 68
# REV_train: $14.993       REV_val: $20.583         REV_test: $15.349
# ------------------------------------------------------------------------------------------
# episode: 69
# REV_train: $12.533       REV_val: $20.107         REV_test: $14.39
# ------------------------------------------------------------------------------------------
# episode: 70
# REV_train: $10.603       REV_val: $22.767         REV_test: $14.51
# ------------------------------------------------------------------------------------------
# episode: 71
# REV_train: $12.851       REV_val: $29.72          REV_test: $17.743
# ------------------------------------------------------------------------------------------
# episode: 72
# REV_train: $19.562       REV_val: $31.201         REV_test: $16.3
# ------------------------------------------------------------------------------------------
# episode: 73
# REV_train: $18.383       REV_val: $30.232         REV_test: $17.81
# ------------------------------------------------------------------------------------------
# episode: 74
# REV_train: $18.119       REV_val: $28.345         REV_test: $17.423
# ------------------------------------------------------------------------------------------
# episode: 75
# REV_train: $16.427       REV_val: $27.72          REV_test: $18.073
# ------------------------------------------------------------------------------------------
# episode: 76
# REV_train: $15.947       REV_val: $31.16          REV_test: $18.042
# ------------------------------------------------------------------------------------------
# episode: 77
# REV_train: $19.292       REV_val: $31.418         REV_test: $18.34
# ------------------------------------------------------------------------------------------
# episode: 78
# REV_train: $17.717       REV_val: $32.363         REV_test: $19.178
# ------------------------------------------------------------------------------------------
# episode: 79
# REV_train: $20.887       REV_val: $39.568         REV_test: $22.823
# ------------------------------------------------------------------------------------------
# episode: 80
# REV_train: $21.855       REV_val: $33.715         REV_test: $19.736
# ------------------------------------------------------------------------------------------
# episode: 81
# REV_train: $17.32        REV_val: $32.611         REV_test: $19.254
# ------------------------------------------------------------------------------------------
# episode: 82
# REV_train: $18.765       REV_val: $32.083         REV_test: $17.452
# ------------------------------------------------------------------------------------------
# episode: 83
# REV_train: $18.577       REV_val: $31.444         REV_test: $18.012
# ------------------------------------------------------------------------------------------
# episode: 84
# REV_train: $20.191       REV_val: $31.347         REV_test: $19.108
# ------------------------------------------------------------------------------------------
# episode: 85
# REV_train: $20.252       REV_val: $33.506         REV_test: $20.682
# ------------------------------------------------------------------------------------------
# episode: 86
# REV_train: $18.109       REV_val: $22.825         REV_test: $15.531
# ------------------------------------------------------------------------------------------
# episode: 87
# REV_train: $14.509       REV_val: $25.53          REV_test: $16.772
# ------------------------------------------------------------------------------------------
# episode: 88
# REV_train: $18.692       REV_val: $26.883         REV_test: $17.885
# ------------------------------------------------------------------------------------------
# episode: 89
# REV_train: $17.674       REV_val: $28.393         REV_test: $17.966
# ------------------------------------------------------------------------------------------
# episode: 90
# REV_train: $19.659       REV_val: $24.003         REV_test: $15.708
# ------------------------------------------------------------------------------------------
# episode: 91
# REV_train: $11.392       REV_val: $13.231         REV_test: $9.519
# ------------------------------------------------------------------------------------------
# episode: 92
# REV_train: $6.755        REV_val: $14.486         REV_test: $10.382
# ------------------------------------------------------------------------------------------
# episode: 93
# REV_train: $6.986        REV_val: $17.481         REV_test: $11.819
# ------------------------------------------------------------------------------------------
# episode: 94
# REV_train: $6.648        REV_val: $12.917         REV_test: $9.31
# ------------------------------------------------------------------------------------------
# episode: 95
# REV_train: $8.139        REV_val: $20.829         REV_test: $13.358
# ------------------------------------------------------------------------------------------
# episode: 96
# REV_train: $13.065       REV_val: $22.674         REV_test: $14.392
# ------------------------------------------------------------------------------------------
# episode: 97
# REV_train: $16.086       REV_val: $24.707         REV_test: $15.944
# ------------------------------------------------------------------------------------------
# episode: 98
# REV_train: $18.045       REV_val: $29.544         REV_test: $18.356
# ------------------------------------------------------------------------------------------
# episode: 99
# REV_train: $18.774       REV_val: $31.29          REV_test: $18.596
# ------------------------------------------------------------------------------------------
# episode: 100
# REV_train: $18.27        REV_val: $30.986         REV_test: $17.968
# ------------------------------------------------------------------------------------------

# %%
model3_test = LSTM()
model3_test.load_state_dict(torch.load('MODEL3.pt'))

bat_val = []; bat_test = []
cha_val = []; cha_test = []
dis_val = []; dis_test = []
rev_val = []; rev_test = []

state = env_val.reset()
history = (torch.zeros([n_layers, 1, hidden_size], dtype=torch.float), torch.zeros([n_layers, 1, hidden_size], dtype=torch.float))
for k in range(len(env_val.data_imb)-1):
    pi_out, next_history = model3_test.pi(torch.tensor(state[-1], dtype=torch.float), history)
    action = pi_out[0].tolist()
    next_state, reward, done, info = env_val.step(action)

    state = next_state[:]
    history = next_history

    bat = info[0]; cha = info[1]; dis = info[2]; revenue = info[3]
    bat_val += [bat]
    cha_val += [cha]
    dis_val += [dis]
    rev_val += [revenue]

state = env_test.reset()
history = (torch.zeros([n_layers, 1, hidden_size], dtype=torch.float), torch.zeros([n_layers, 1, hidden_size], dtype=torch.float))
for l in range(len(env_test.data_imb)-1):
    pi_out, next_history = model3_test.pi(torch.tensor(state[-1], dtype=torch.float), history)
    action = pi_out[0].tolist()
    next_state, reward, done, info = env_test.step(action)

    state = next_state[:]
    history = next_history

    bat = info[0]; cha = info[1]; dis = info[2]; revenue = info[3]
    bat_test += [bat]
    cha_test += [cha]
    dis_test += [dis]
    rev_test += [revenue]

REV_val   = round(max_price*100*np.mean(rev_val),3)
REV_test  = round(max_price*100*np.mean(rev_test),3)
print("REV_val: ${}".format(REV_val).ljust(25), end="")
print("REV_test: ${}".format(REV_test).ljust(25))
print("------------------------------------------------------------------------------------------")

plt.plot(bat_test)
# Out:
# <ipython-input-12-cbdf1e6eda71>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model3_test.load_state_dict(torch.load('MODEL3.pt'))
# REV_val: $39.568         REV_test: $22.823
# ------------------------------------------------------------------------------------------
